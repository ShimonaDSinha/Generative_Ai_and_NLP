# %%
# !pip install transformers torch

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
qa_pipeline = pipeline(
    "question-answering",
    model="distilbert-base-cased-distilled-squad"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Device set to use cpu

# %%
qa_pipeline = pipeline(
    "question-answering",
    model="distilbert-base-cased-distilled-squad"
)
# Out:
# Device set to use cpu

# %%
context = """
Generative AI poses several risks including hallucinations,
algorithmic bias, misinformation, data privacy concerns,
and the creation of deepfake content.
"""

# %%
question = "What are the risks of Generative AI?"

# %%
result = qa_pipeline(
    question=question,
    context=context
)

print("Answer:", result["answer"])
print("Confidence Score:", result["score"])
# Out:
# Answer: hallucinations,
# algorithmic bias, misinformation
# Confidence Score: 0.01787371002137661

# %%
questions = [
    "What are the risks?",
    "Does Generative AI cause bias?",
    "What content can be misused?"
]

for q in questions:
    output = qa_pipeline(question=q, context=context)
    print("\nQuestion:", q)
    print("Answer:", output["answer"])
# Out:
# Question: What are the risks?
# Answer: data privacy concerns,
# and the creation of deepfake content
#
# Question: Does Generative AI cause bias?
# Answer: Generative AI poses several risks
#
# Question: What content can be misused?
# Answer: deepfake

# %% [markdown]
# **Architecture Explanation**
#
# Why this model works?
#
# DistilBERT is an encoder-only transformer architecture trained to understand context and predict answer spans within a document.
# Because it is fine-tuned on the SQuAD dataset, it performs extractive Question Answering effectively by identifying the most relevant text segment.

# %% [markdown]
# **Limitation**
# This model cannot generate new answers. It can only extract answers that already exist in the given context. If the answer is not present, the output may be incomplete or incorrect.

# %% [markdown]
# **Applications**
#
#
# *   Customer support bots
# *   FAQ systems
# *   Educational assistants
#
#  **Conclusion**
#
# This project demonstrates how Hugging Face QA pipelines can be used to build efficient and accurate question answering systems using encoder-based transformer models.

# %%
qa_base = pipeline("question-answering", model="bert-base-uncased")

qa_base(question=question, context=context)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Device set to use cpu
# {'score': 0.007518943166360259,
#  'start': 45,
#  'end': 72,
#  'answer': 'hallucinations,\nalgorithmic'}

# %% [markdown]
# The base BERT model performs worse as it is not fine-tuned for QA.
